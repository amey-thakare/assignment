# %%
#Task 1
products=['pen','pencil','eraser','chips','glass','phone','book']
sample_product=('pen',10,'stationary')

# %%
print(products[1])
# Out:
# pencil

# %%
print(products[-1])
# Out:
# book

# %%
products.append('mouse')

# %%
products.append('scale')

# %%
print(products)
# Out:
# ['pen', 'pencil', 'eraser', 'chips', 'glass', 'phone', 'book', 'mouse', 'scale']

# %%
l=list(sample_product)

# %%
l[1]=25

# %%
editedSampleProducts=tuple(l)

# %%
print(editedSampleProducts)
# Out:
# ('pen', 25, 'stationary')

# %%
# Task2

# %%
categories=['stationary','stationary','stationary','snacks','material','electronics','stationary','electronics','stationary']

# %%
category_set=set(categories)

# %%
category_set
# Out:
# {'electronics', 'material', 'snacks', 'stationary'}

# %%
print('material' in category_set)
# Out:
# True

# %%
print(len(category_set))
# Out:
# 4

# %%
#Task 3
price_dict={
    'pen':25,
    'pencil':5,
    'eraser':2,
    'chips':10,
    'book':100,
    'scale':7
}

# %%
price_dict['tab']=25000

# %%
price_dict['scale']=8

# %%
price_dict
# Out:
# {'pen': 25,
#  'pencil': 5,
#  'eraser': 2,
#  'chips': 10,
#  'book': 100,
#  'scale': 8,
#  'tab': 25000}

# %%
del price_dict['pen']

# %%
price_dict
# Out:
# {'pencil': 5, 'eraser': 2, 'chips': 10, 'book': 100, 'scale': 8, 'tab': 25000}

# %%
total=sum(price_dict.values())

# %%
total
# Out:
# 25125

# %%
avg=total/len(price_dict)

# %%
avg
# Out:
# 4187.5

# %%
print(max(price_dict,key=price_dict.get))
# Out:
# tab

# %%
print(min(price_dict,key=price_dict.get))
# Out:
# eraser

# %%
#Task 4
products
# Out:
# ['pen',
#  'pencil',
#  'eraser',
#  'chips',
#  'glass',
#  'phone',
#  'book',
#  'mouse',
#  'scale']

# %%
price_dict
# Out:
# {'pencil': 5, 'eraser': 2, 'chips': 10, 'book': 100, 'scale': 8, 'tab': 25000}

# %%
del products[0]

# %%
products
# Out:
# ['pencil', 'eraser', 'chips', 'glass', 'phone', 'book', 'mouse', 'scale']

# %%
del products[3]

# %%
del products[3]

# %%
products
# Out:
# ['pencil', 'eraser', 'chips', 'book', 'mouse', 'scale']

# %%
del products[4]

# %%
products.append('tab')

# %%
products
# Out:
# ['pencil', 'eraser', 'chips', 'book', 'scale', 'tab']

# %%
categories
# Out:
# ['stationary',
#  'stationary',
#  'stationary',
#  'snacks',
#  'material',
#  'electronics',
#  'stationary',
#  'electronics',
#  'stationary']

# %%
del categories[6:8]

# %%
categories
# Out:
# ['stationary',
#  'stationary',
#  'stationary',
#  'snacks',
#  'material',
#  'electronics',
#  'stationary']

# %%
del categories[6]

# %%
categories
# Out:
# ['stationary', 'stationary', 'stationary', 'snacks', 'material', 'electronics']

# %%
catalog=[]
for i in range(0,len(categories)):
    catalog.append((products[i],price_dict[products[i]],categories[i]))

# %%
print(catalog)
# Out:
# [('pencil', 5, 'stationary'), ('eraser', 2, 'stationary'), ('chips', 10, 'stationary'), ('book', 100, 'snacks'), ('scale', 8, 'material'), ('tab', 25000, 'electronics')]

# %%
category_to_products={}
for product,price,category in catalog:
    if category not in category_to_products:
        category_to_products[category]=[]
    category_to_products[category].append(product)

# %%
print(    category_to_products)
# Out:
# {'stationary': ['pencil', 'eraser', 'chips'], 'snacks': ['book'], 'material': ['scale'], 'electronics': ['tab']}
